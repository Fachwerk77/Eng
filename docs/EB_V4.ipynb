# %% [markdown]
# # Präambel - Bauwesen-Chatbot: Intelligenter Berechnungs- und Nachweisassistent
#
# ## 1. Einführung
# Der Bauwesen-Chatbot ist ein innovatives KI-gestütztes System, das Bauingenieure und Architekten bei der Durchführung von Berechnungen und der Erstellung von Nachweisen unterstützt. Das System vereint modernste Technologien der künstlichen Intelligenz mit fundiertem Fachwissen aus dem Bauwesen.
#
# ## 2. Zielsetzung
# Das primäre Ziel ist die Entwicklung eines intelligenten Assistenzsystems, das:
# - Komplexe baustatische Berechnungen automatisiert
# - Normgerechte Nachweise erstellt
# - Fachspezifische Beratung anbietet
# - Den Planungsprozess beschleunigt
# - Qualitätssicherung gewährleistet
#
# ## 3. Technische Grundlagen
#
# ### 3.1 Kernkomponenten
# - Sprachverarbeitungsmodul: GPT-basierte NLP-Verarbeitung
# - Wissensdatenbank: Strukturierte Speicherung von Bauvorschriften und Normen
# - Berechnungsengine: Integration von SymPy und NumPy
# - Dokumentationssystem: LaTeX-basierte Nachweiserstellung
# - API-Schnittstelle: RESTful-API für externe Kommunikation
#
# ### 3.2 Datenmanagement
# - Datenbank-Schema: PostgreSQL für strukturierte Datenhaltung
# - Caching-System: Redis für temporäre Berechnungsergebnisse
# - Versionierung: Git für Code und Dokumentation
# - Backup-System: Automatisierte Sicherungen
#
# ### 3.3 Verwendete Bibliotheken
# - NLTK: Sprachverarbeitung und Tokenisierung
# - TensorFlow/PyTorch: Modellierung und maschinelles Lernen
# - pandas: Datenverwaltung und Analyse
# - scikit-learn: Modelltraining und Validierung
# - Flask: Integration mit Webanwendungen
# - Spacy: NLP-Toolkits für linguistische Funktionen
# - NumPy: Für präzise numerische Berechnungen
# - SymPy: Für symbolische mathematische Operationen
#
# ### 3.4 Spezifische Bauwesen-Funktionalitäten
# - Statische Berechnungen: Implementierung von Tragwerksberechnungen
# - Normgerechte Nachweise: Automatisierte Erstellung von Nachweisen nach Eurocode
# - Bauteilbemessung: Dimensionierung von Stahl- und Stahlbetonbauteilen
# - Lastfall-Analysen: Berechnung und Dokumentation verschiedener Lastszenarien
#
# ### 3.5 Mathematische Grundlagen
# - SymPy: Symbolische Berechnung von Schnittgrößen und Verformungen
# - NumPy: Numerische Lösung von Differentialgleichungen und Matrizenoperationen
# - LaTeX: Professionelle Dokumentation von Nachweisen und Berechnungen
#
# ## 4. Implementierung und Entwicklung
#
# ### 4.1 Beispielhafte Anwendungsfälle
# - Statische Berechnungen für Standardbauteile
# - Automatisierte Nachweiserstellung nach Eurocode
# - Interaktive Bemessung von Stahlbetonbauteilen
# - Dynamische Lastfallanalysen
# - Optimierung von Tragwerksstrukturen
#
# ### 4.2 Implementierungsphasen
# - Phase 1: Grundlegende Systemarchitektur
# - Phase 2: Integration der Kernfunktionalitäten
# - Phase 3: Entwicklung der Benutzeroberfläche
# - Phase 4: Testphase und Qualitätssicherung
# - Phase 5: Pilotbetrieb und Optimierung
#
# ### 4.3 Entwicklungsumgebung
# - Python als Hauptprogrammiersprache
# - Docker für Containerisierung
# - Git für Versionskontrolle
# - CI/CD-Pipeline für kontinuierliche Integration
# - Testautomatisierung mit pytest
#
# ### 4.4 Sicherheit und Datenschutz
# - Verschlüsselte Datenübertragung
# - Rollenbasierte Zugriffssteuerung
# - Regelmäßige Sicherheitsaudits
# - DSGVO-konforme Datenspeicherung
# - Backup- und Recovery-Strategien
#
# ### 4.5 Monitoring und Wartung
# - Systemüberwachung in Echtzeit
# - Automatisierte Fehlererkennung
# - Regelmäßige Wartungsintervalle
# - Performance-Optimierung
# - Skalierbarkeitsanpassungen
#
# ## 5. Qualitätssicherung und Standards
#
# ### 5.1 Bauspezifische Standards und Integration
# - Eurocode-Konformität
# - DIN-Normen-Integration
# - BIM-Kompatibilität
# - Schnittstellen zu CAD-Systemen
# - Anbindung an Facility Management
#
# ### 5.2 Qualitätssicherungsmaßnahmen
# - Automatisierte Testsuiten für Berechnungsfunktionen
# - Code-Reviews und Dokumentationsstandards
# - Kontinuierliche Integration und Deployment (CI/CD)
# - Reguläre Validierung der Berechnungsergebnisse
# - Konformitätsprüfung mit aktuellen Baustandards
# - Dokumentierte Teststrategie und -protokolle
#
# ### 5.3 Dokumentationsstandards
# - Ausführliche API-Dokumentation
# - Benutzerhandbücher und Anleitungen
# - Technische Spezifikationen
# - Wartungs- und Betriebshandbücher
# - Versionierungsrichtlinien
# - Änderungsprotokolle
#
# ## 6. Beispielanfragen
#
# ### 6.1 Komplexe semantische Anfrage
# "Ich möchte einen Nachweis für einen Stahlträger IPE 200 durchführen. Der Träger ist 5,5m lang und wird durch eine gleichmäßig verteilte Last von 25 kN/m sowie eine Einzellast von 15 kN in Feldmitte belastet. Die Auflagerbedingungen sind beidseitig gelenkig. Material ist S235."
#
# ### 6.2 Anfrage nach Nachweis Kopfbolzendübel
# "Bitte führe einen Nachweis für Kopfbolzendübel durch. Es handelt sich um 4 Stück KBD 22/100 im Verbund mit einer Betonplatte C25/30. Die charakteristische Längsschubkraft beträgt 250 kN. Die Kopfbolzen sind in einer Reihe angeordnet.
#
# Die Analyse und alle Berechnungsergebnisse (einschließlich Zwischenergebnisse) müssen in einer separaten Zelle im standardisierten LaTeX-Format ausgegeben werden. Dies ermöglicht die direkte Weiterverarbeitung der Ergebnisse in anderen Softwaresystemen oder über API-Schnittstellen. Das LaTeX-Format soll dabei alle mathematischen Formeln, Zwischenschritte und Endergebnisse strukturiert darstellen."
#
# ## 7. Ausblick und Perspektiven
#
# Der entwickelte Chatbot als Single Source of Truth bietet weitreichende Entwicklungsmöglichkeiten für zukünftige Anwendungsfälle:
#
# ### 7.1 Automatisierte BIM-Modellierung
# - Integration des Chatbots in BIM-Workflows
# - Automatische Überprüfung und Validierung von Modellierungsstandards
# - Unterstützung bei der konsistenten Modellerstellung
#
# ### 7.2 Intelligente Planprüfung
# - Automatisierte Überprüfung von Bauplänen gegen:
#   - Offizielle Normen und Standards
#   - Unternehmensspezifische Richtlinien
#   - Projektspezifische Anforderungen
# - Früherkennung von Planungsfehlern und Inkonsistenzen
#
# ### 7.3 Potenzielle Ausbaustufen
# 1. Grundlegende Normprüfung
# 2. Integration firmenspezifischer Regelwerke
# 3. KI-gestützte Optimierungsvorschläge
# 4. Vollautomatische Validierung komplexer Planungsunterlagen
#
# Diese Weiterentwicklungen werden die Effizienz und Qualität in der Bauplanung weiter steigern und zur Standardisierung von Planungsprozessen beitragen.

# %% [markdown]
# ## 0.0 GPU und Systemkonfiguration
# In diesem Abschnitt wird die GPU- und Systemkonfiguration des Bauwesen-Chatbots beschrieben. Dies umfasst die Optimierung der GPU-Nutzung, Aktivierung von Mixed-Precision-Training sowie die Verwaltung von Umgebungsvariablen für eine effiziente Berechnung.

# %% [markdown]
# ### 0.0.1 Basis-Bibliotheken Installation

# %%
# Basis-Bibliotheken Installation
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: numpy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.0.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pandas in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: matplotlib in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib) (2.8.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: seaborn in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)

# %% [markdown]
# ###  0.0.2 Machine Learning Bibliotheken

# %%
# Machine Learning Bibliotheken
# !pip install tensorflow
# !pip install torch torchvision
# !pip install scikit-learn
# !pip install xgboost
# !pip install lightgbm
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: tensorflow in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/lib/python3/dist-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2023.11.17)
# Requirement already satisfied: markdown>=2.6.8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/lib/python3/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/lib/python3/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: torch in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (0.21.0)
# Requirement already satisfied: filelock in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch) (2.1.5)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: scikit-learn in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: xgboost in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.1.4)
# Requirement already satisfied: numpy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from xgboost) (1.15.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: lightgbm in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from lightgbm) (1.15.2)

# %% [markdown]
# ### 0.0.3 Konsolidierte Entwicklungswerkzeuge und zusätzliche Bibliotheken
# !pip install jupyter

# %%
# Konsolidierte Entwicklungswerkzeuge und zusätzliche Bibliotheken
# !pip install jupyter
# !pip install ipywidgets
# !pip install black
# !pip install pylint
# !pip install autopep8
# !pip install notebook
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: jupyter in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: notebook in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter) (4.3.5)
# Requirement already satisfied: comm>=0.1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (9.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (24.2)
# Requirement already satisfied: psutil in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-console->jupyter) (3.0.50)
# Requirement already satisfied: pygments in /usr/lib/python3/dist-packages (from jupyter-console->jupyter) (2.17.2)
# Requirement already satisfied: async-lru>=1.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter) (75.8.2)
# Requirement already satisfied: beautifulsoup4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/lib/python3/dist-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.8.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.7)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: stack_data in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /usr/lib/python3/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.10.3)
# Requirement already satisfied: json5>=0.9.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: wcwidth in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/lib/python3/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/lib/python3/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: ptyprocess in /usr/lib/python3/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/lib/python3/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0)
# Requirement already satisfied: uri-template in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from rfc3339-validator->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241206)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: ipywidgets in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets) (9.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack_data in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: black in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (25.1.0)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from black) (8.1.6)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from black) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from black) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from black) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from black) (4.3.6)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pylint in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (3.3.4)
# Requirement already satisfied: dill>=0.3.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (0.3.8)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (4.3.6)
# Requirement already satisfied: astroid<=3.4.0-dev0,>=3.3.8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (3.3.8)
# Requirement already satisfied: isort!=5.13.0,<7,>=4.2.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (6.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pylint) (0.13.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: autopep8 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: pycodestyle>=2.12.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from autopep8) (2.12.1)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: notebook in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (7.3.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from notebook) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from notebook) (4.3.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from notebook) (6.4.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.5)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.2)
# Requirement already satisfied: prometheus-client>=0.9 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook) (75.8.2)
# Requirement already satisfied: babel>=2.10 in /usr/lib/python3/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.10.3)
# Requirement already satisfied: json5>=0.9.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (9.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (1.6.0)
# Requirement already satisfied: psutil in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (7.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/lib/python3/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/lib/python3/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/lib/python3/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.17.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.0.7)
# Requirement already satisfied: ptyprocess in /usr/lib/python3/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: webencodings in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: decorator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (3.0.50)
# Requirement already satisfied: stack_data in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.6.3)
# Requirement already satisfied: fqdn in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/lib/python3/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.0)
# Requirement already satisfied: uri-template in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.6)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from rfc3339-validator->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: pycparser in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.8.4)
# Requirement already satisfied: wcwidth in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (3.0.0)
# Requirement already satisfied: pure-eval in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20241206)

# %% [markdown]
# ### 0.0.4 Spezifische Bibliotheken

# %%
# Spezifische Bibliotheken
# !pip install nltk  # Verarbeitung natürlicher Sprache
# !pip install spacy  # NLP-Bibliothek
# !pip install sympy  # Symbolische Mathematik
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: nltk in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from nltk) (4.67.1)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: spacy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (75.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.6)
# Requirement already satisfied: shellingham>=1.3.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/lib/python3/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/lib/python3/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.17.2)
# Requirement already satisfied: wrapt in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: sympy in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from sympy) (1.3.0)

# %% [markdown]
# ### 0.0.5 Web-Framework und Datenbank

# %%
# Web-Framework und Datenbank
# !pip install flask  # Flask für Webentwicklung
# !pip install psycopg2-binary  # Anbindung an PostgreSQL-Datenbanken
# !pip install redis # Redis-Datenbankintegration
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: flask in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: Werkzeug>=2.3.3 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from flask) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/lib/python3/dist-packages (from flask) (8.1.6)
# Requirement already satisfied: blinker>=1.6.2 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: psycopg2-binary in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.9.10)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: redis in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (5.0.0)

# %% [markdown]
# ### 0.0.6 Entwicklungswerkzeuge

# %%
# Entwicklungswerkzeuge
# !pip install pandas  # Datenverarbeitung
# !pip install pytest  # Testautomatisierung
# !pip install python-dotenv # Verwalten von Umgebungsvariablen
# !pip install pyyaml  # YAML-Verarbeitung
# !pip install python-latex # LaTeX-Unterstützung
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pandas in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pytest in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (7.4.0)
# Requirement already satisfied: iniconfig in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pytest) (24.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from pytest) (1.5.0)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: python-dotenv in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (1.0.0)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (6.0.1)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: python-latex in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: latex in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from python-latex) (0.7.0)
# Requirement already satisfied: watchdog in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from python-latex) (6.0.0)
# Requirement already satisfied: tempdir in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from latex->python-latex) (0.7.1)
# Requirement already satisfied: data in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from latex->python-latex) (0.4)
# Requirement already satisfied: future in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from latex->python-latex) (1.0.0)
# Requirement already satisfied: shutilwhich in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from latex->python-latex) (1.1.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from data->latex->python-latex) (1.16.0)
# Requirement already satisfied: decorator in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from data->latex->python-latex) (5.2.1)
# Requirement already satisfied: funcsigs in /home/icl/Projekte/EngBot/.venv/lib/python3.12/site-packages (from data->latex->python-latex) (1.0.2)

# %% [markdown]
# ## T0.1 Bibliotheken Import
# Import aller notwendigen Bibliotheken und APIs für das Projekt.

# %%
from typing import Dict, Optional
import logging
import tensorflow as tf


def check_gpu_status() -> Dict:
def gpu_status_check() -> Dict[str, Optional[object]]:
    """
    Überprüft den GPU-Status und gibt detaillierte Informationen zurück.
    Führt eine umfassende GPU-Status-Prüfung durch, einschließlich CUDA-Verfügbarkeit,
    GPU-Details, Speicherstatus und TensorFlow-Version.

    Returns:
        Dict: Ein Dictionary mit GPU-Statusinformationen
        Dict[str, Optional[object]]: Ein Dictionary mit den GPU-Status-Informationen.
    """
    status = {
        'gpu_verfuegbar': False,
        "gpu_verfuegbar": False,
        "cuda_verfuegbar": False,
        'gpu_name': None,
        "gpu_name": None,
        'gpu_speicher_gesamt': None,
        "gpu_speicher_gesamt_gb": None,
        'gpu_speicher_frei': None,
        'cuda_verfuegbar': False,
        "gpu_speicher_frei_gb": None,
        'tensorflow_version': tf.__version__
        "tensorflow_version": tf.__version__,
    }

    logger = logging.getLogger(__name__)
    logger.info(f"TensorFlow Version: {status['tensorflow_version']}")
    logger.info(f"Prüfe TensorFlow Version: {status['tensorflow_version']}")

    try:
        # CUDA-Verfügbarkeit prüfen
        status['cuda_verfuegbar'] = tf.test.is_built_with_cuda()
        status["cuda_verfuegbar"] = tf.test.is_built_with_cuda()
        if status['cuda_verfuegbar']:
        if status["cuda_verfuegbar"]:
            logger.info("CUDA ist verfügbar")
            logger.info("CUDA ist verfügbar.")
        else:
            logger.warning("CUDA ist nicht verfügbar. Bitte überprüfen Sie, ob CUDA korrekt installiert ist.")
            logger.error("Ohne CUDA kann die GPU-Beschleunigung nicht genutzt werden.")
            return status
            logger.warning("CUDA ist nicht verfügbar. GPU-Unterstützung könnte eingeschränkt sein.")

        # GPU-Erkennung über TensorFlow
        # GPU-Erkennung prüfen
        gpus = tf.config.list_physical_devices('GPU')
        gpus = tf.config.list_physical_devices("GPU")
        if gpus:
            status['gpu_verfuegbar'] = True
            status["gpu_verfuegbar"] = True
            logger.info(f"{len(gpus)} GPU(s) gefunden")
            logger.info(f"{len(gpus)} GPU(s) erkannt.")

            # Versuche GPU-Details über nvidia-smi zu bekommen
            for gpu in gpus:
                # GPU-Details auslesen
            nvidia_info = get_nvidia_smi_output()
            if nvidia_info:
                details = tf.config.experimental.get_device_details(gpu)
                gpu_name = details.get("device_name", "Unbekannte GPU")
                status['gpu_name'] = nvidia_info['name']
                status["gpu_name"] = gpu_name
                status['gpu_speicher_gesamt'] = nvidia_info['memory_total']
                status['gpu_speicher_frei'] = nvidia_info['memory_free']
                logger.info(f"Entdeckte GPU: {gpu_name}")

                logger.info(f"GPU: {status['gpu_name']}")
                # Speicherinformationen abrufen
                try:
                    memory_info = tf.config.experimental.get_memory_info(gpu.name)
                    total_memory_gb = memory_info["total"] / (1024 ** 3)  # In GB
                logger.info(f"GPU-Speicher gesamt: {status['gpu_speicher_gesamt']} MB")
                    free_memory_gb = memory_info["free"] / (1024 ** 3)  # In GB
                    status["gpu_speicher_gesamt_gb"] = round(total_memory_gb, 2)
                logger.info(f"GPU-Speicher frei: {status['gpu_speicher_frei']} MB")
                    status["gpu_speicher_frei_gb"] = round(free_memory_gb, 2)

                # Warnung bei niedrigem Speicher
                if status['gpu_speicher_frei'] < 500:  # Beispielgrenzwert
                    logger.info(f"GPU-Speicher gesamt: {total_memory_gb:.2f} GB")
                    logger.warning("Achtung: Der freie GPU-Speicher ist sehr niedrig (< 500 MB).")
                    logger.info(f"GPU-Speicher frei: {free_memory_gb:.2f} GB")
                elif status['gpu_speicher_frei'] < 1000:
                except AttributeError:
                    logger.info("Hinweis: Der freie GPU-Speicher ist moderat (< 1000 MB).")
                    logger.warning("Speicherinformationen für GPU konnten nicht abgerufen werden.")

            else:
        else:
                logger.warning("Konnte keine Details über nvidia-smi abrufen.")
            logger.warning("Keine GPUs verfügbar.")

            # Speicherwachstum aktivieren
            try:
                for gpu in gpus:
                    tf.config.experimental.set_memory_growth(gpu, True)
        # Speicherwachstum aktivieren
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
                logger.info("Dynamische Speicherzuweisung für GPUs aktiviert.")
            logger.info("GPU-Speichermanagement mit dynamischer Speicherzuweisung aktiviert.")
            except Exception as e:
                logger.warning(f"Konnte dynamische Speicherzuweisung nicht aktivieren: {e}")
        except Exception as e:
            logger.warning(f"Konnte dynamische Speicherzuweisung nicht aktivieren: {e}")
        else:
            logger.warning("Keine GPUs gefunden.")

    except Exception as e:
        logger.error(f"Allgemeiner Fehler beim GPU-Check: {e}")
        logger.error(f"Fehler beim GPU-Status-Check: {e}")

    # Abschlussbericht
    # Zusammenfassung
    logger.info("\n=== GPU-Status Zusammenfassung ===")
    logger.info("=== GPU-Status Zusammenfassung ===")
    logger.info(f"GPU verfügbar: {status['gpu_verfuegbar']}")
    logger.info(f"TensorFlow-Version: {status['tensorflow_version']}")
    logger.info(f"CUDA verfügbar: {status['cuda_verfuegbar']}")
    logger.info(f"GPU Name: {status['gpu_name']}")
    logger.info(f"GPU verfügbar: {status['gpu_verfuegbar']}")
    if status["gpu_name"]:
    if status['gpu_speicher_gesamt']:
        logger.info(f"GPU-Name: {status['gpu_name']}")
        logger.info(f"Gesamt-Speicher: {status['gpu_speicher_gesamt']} MB")
        logger.info(f"GPU-Speicher gesamt: {status['gpu_speicher_gesamt_gb']} GB")
        logger.info(f"Freier Speicher: {status['gpu_speicher_frei']} MB")
        logger.info(f"GPU-Speicher frei: {status['gpu_speicher_frei_gb']} GB")
    logger.info("================================\n")
    logger.info("===================================")

    return status

# %%
import shutil
import logging

def check_nvidia_smi_available() -> bool:
    """
    Überprüft, ob nvidia-smi verfügbar ist und gibt den Pfad zurück.
    Protokolliert relevante Informationen.
    """
    logger = logging.getLogger(__name__)
    nvidia_smi_path = shutil.which("nvidia-smi")

    if nvidia_smi_path:
        logger.info(f"nvidia-smi verfügbar: {nvidia_smi_path}")
        return True
    else:
        logger.warning("nvidia-smi ist nicht verfügbar.")
        return False

# Aufruf der Funktion
check_nvidia_smi_available()
# Out:
# 2025-03-05 10:59:36,167 - INFO - nvidia-smi verfügbar: /usr/bin/nvidia-smi
# True

# %%
# =============================== #
# GPU-Status-Check Funktion    #
# =============================== #

def check_gpu_status() -> None:
    """
    Überprüft die GPU-Verfügbarkeit und protokolliert die relevanten Informationen,
    einschließlich Name der GPU, verfügbarer und genutzter Speicher.
    """
    import tensorflow as tf
    import logging

    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            logging.info(f"{len(gpus)} GPU(s) gefunden.")
            for gpu in gpus:
                details = tf.config.experimental.get_device_details(gpu)
                gpu_name = details.get("device_name", "Unbekannte GPU")
                logging.info(f"GPU: {gpu_name}")

                # Ermittlung des Speicherstatus unter Verwendung von `tf.config.experimental`
                # Hinweis: `get_memory_info()` könnte je nach TensorFlow-Version nicht verfügbar sein.
                try:
                    memory_info = tf.config.experimental.get_memory_info(gpu.name)
                    total_memory_mb = memory_info['total'] / (1024 * 1024)  # In MB
                    free_memory_mb = memory_info['free'] / (1024 * 1024)  # In MB
                except AttributeError:
                    logging.warning("Speicherinformationen konnten nicht abgerufen werden.")
                    continue

                # Speicherstatus in MB und zusätzlich in GB anzeigen
                logging.info(f"Speicher (MB): Total: {total_memory_mb:.2f} MB, Frei: {free_memory_mb:.2f} MB")
                logging.info(f"Speicher (GB): Total: {total_memory_mb / 1024:.2f} GB, Frei: {free_memory_mb / 1024:.2f} GB")

        except Exception as e:
            logging.error(f"Ein Fehler ist beim GPU-Status-Check aufgetreten: {str(e)}")
    else:
        logging.info("Keine GPUs gefunden.")

# Aufruf der Funktion zur Ausgabe des GPU-Status
check_gpu_status()
# Out:
# 2025-03-05 10:59:41,312 - INFO - 1 GPU(s) gefunden.
# 2025-03-05 10:59:41,314 - INFO - GPU: NVIDIA RTX 3000 Ada Generation Laptop GPU
# 2025-03-05 10:59:41,315 - ERROR - Ein Fehler ist beim GPU-Status-Check aufgetreten: Failed parsing device name: '/physical_device:GPU:0'. Note a valid device string should at least contain a device type and a device index, like "GPU:0".

# %%
def check_tensorflow_version_and_devices() -> None:
    """
    Gibt die TensorFlow-Version aus und listet die verfügbaren Geräte auf.
    """
    import tensorflow as tf
    print(f"TensorFlow-Version: {tf.__version__}")
    devices = tf.config.list_physical_devices()
    if devices:
        print("Verfügbare Geräte:")
        for device in devices:
            print(f"- {device.device_type}: {device.name}")
    else:
        print("Keine verfügbaren Geräte gefunden.")

# Funktion aufrufen, um Informationen auszugeben
check_tensorflow_version_and_devices()
# Out:
# TensorFlow-Version: 2.18.0
# Verfügbare Geräte:
# - CPU: /physical_device:CPU:0
# - GPU: /physical_device:GPU:0
